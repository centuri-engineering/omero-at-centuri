# %%
import sys
sys.version
# Out:
# '3.6.7 | packaged by conda-forge | (default, Nov  6 2019, 16:19:42) \n[GCC 7.3.0]'

# %%
sys.path
# Out:
# ['/home/guillaume/Dev',
#  '/home/guillaume/Centuri/Omero/Code/omero-at-centuri/pyutils',
#  '/home/guillaume/miniconda3/envs/pyomero/lib/python36.zip',
#  '/home/guillaume/miniconda3/envs/pyomero/lib/python3.6',
#  '/home/guillaume/miniconda3/envs/pyomero/lib/python3.6/lib-dynload',
#  '',
#  '/home/guillaume/miniconda3/envs/pyomero/lib/python3.6/site-packages',
#  '/home/guillaume/miniconda3/envs/pyomero/lib/python3.6/site-packages/IPython/extensions',
#  '/home/guillaume/.ipython']

# %%
omero parade

# %%
from sqlalchemy import create_engine 
import pandas as pd

# %%
engine = create_engine("postgresql://omero:omero@localhost/ibdm_omero_database")

# %%
with engine.connect() as conn: 
    originalfile = pd.read_sql_table("originalfile", conn)
# Out:
# /home/guillaume/miniconda3/envs/pyomero/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/base.py:3331: SAWarning: Predicate of partial index originalfile_repo_path_index ignored during reflection
#   % idx_name

# %%
print(*engine.table_names(), sep='\n\t')
# Out:
# _fs_deletelog
# 	_lock_ids
# 	arc
# 	channelannotationlink
# 	annotation
# 	arctype
# 	binning
# 	checksumalgorithm
# 	channelbinding
# 	channel
# 	codomainmapcontext
# 	contrastmethod
# 	datasetannotationlink
# 	configuration
# 	contraststretchingcontext
# 	correction
# 	filesetannotationlink
# 	filtersetemissionfilterlink
# 	count_experimentergroup_annotationlinks_by_owner
# 	datasetimagelink
# 	acquisitionmode
# 	filesetjoblink
# 	count_experimenter_annotationlinks_by_owner
# 	annotationannotationlink
# 	lightpathexcitationfilterlink
# 	namespaceannotationlink
# 	count_node_annotationlinks_by_owner
# 	joboriginalfilelink
# 	imageannotationlink
# 	pixelsannotationlink
# 	planeinfoannotationlink
# 	plateacquisitionannotationlink
# 	plateannotationlink
# 	projectannotationlink
# 	pixelsoriginalfilemap
# 	originalfileannotationlink
# 	roiannotationlink
# 	detector
# 	dataset
# 	screenannotationlink
# 	wellannotationlink
# 	count_session_annotationlinks_by_owner
# 	event
# ...

# %%
originalfile.head()
# Out:
#       id                   atime                   ctime  permissions  \
# 0  44874                     NaT                     NaT          -56
# 1      1 2014-10-21 11:56:01.517 2014-10-21 11:56:01.517         -120
# 2      2 2014-10-21 11:56:01.752 2014-10-21 11:56:01.752         -120
# 3      3 2014-10-21 11:56:01.986 2014-10-21 11:56:01.986         -120
# 4    152                     NaT                     NaT         -120
#
#                                        hash    mimetype  \
# 0  46ec9e62f7c9fa2ac388fbb32a78b0530b3c2146        None
# 1      2ed1f4ce-23ca-448d-890d-5a868ef45693  Repository
# 2      9077bd18-f90d-4109-9a83-baa3944361a8  Repository
# 3                                ScriptRepo  Repository
# 4  7c8703f88174d58c6a071d91224938af702b482d  text/plain
#
#                     mtime                           name  \
# 0 2016-03-08 09:55:24.609  Satb2 SSC 2-3lfusedmerged.tif
# 1 2014-10-21 11:56:01.517                          OMERO
# ...

# %%
originalfile[originalfile['name'].apply(lambda v: 'tif' in v)][['id', 'name']]
# Out:
#           id                                               name
# 0      44874                      Satb2 SSC 2-3lfusedmerged.tif
# 25       394  573819-KLP10A inhibition caused anaphase B-lik...
# 32       400  573821-Live embryo expressing KLP10A-GFP (gree...
# 58       625                                        573824.tiff
# 68       114                            120-Bod1 siRNA.ome.tiff
# ...      ...                                                ...
# 42777  45937  rv_trans_d1gfp_injS1_contra_S1_GFP_Cherry_Cux1...
# 42780  45940  rv_trans_d1gfp_injS1_contra_S1_GFP_Cherry_Cux1...
# 42816  45990                                           Dapi.tif
# 42817  45996                                            GFP.tif
# 42823  45993                                          DsRed.tif
#
# [7900 rows x 2 columns]

# %%
originalfile[originalfile['name'].apply(lambda v: '46.554' in v)]["mimetype"]
# Out:
# Series([], Name: mimetype, dtype: object)

# %%
originalfile[originalfile['name'].apply(lambda v: 'tif' in v)][['id', 'name']]
# Out:
#           id                                               name
# 0      44874                      Satb2 SSC 2-3lfusedmerged.tif
# 25       394  573819-KLP10A inhibition caused anaphase B-lik...
# 32       400  573821-Live embryo expressing KLP10A-GFP (gree...
# 58       625                                        573824.tiff
# 68       114                            120-Bod1 siRNA.ome.tiff
# ...      ...                                                ...
# 42777  45937  rv_trans_d1gfp_injS1_contra_S1_GFP_Cherry_Cux1...
# 42780  45940  rv_trans_d1gfp_injS1_contra_S1_GFP_Cherry_Cux1...
# 42816  45990                                           Dapi.tif
# 42817  45996                                            GFP.tif
# 42823  45993                                          DsRed.tif
#
# [7900 rows x 2 columns]

# %%
with engine.connect() as conn: 
    datasetimagelink = pd.read_sql_table("datasetimagelink", conn)

# %%
datasetimagelink
# Out:
#           id  permissions  version  child  creation_id external_id  group_id  \
# 0        289         -120      0.0    285        24066        None        64
# 1        290         -120      0.0    286        24092        None        64
# 2         52         -120      0.0     52          959        None         0
# 3         53         -120      0.0     53          960        None         0
# 4         54         -120      0.0     54         1000        None         0
# ...      ...          ...      ...    ...          ...         ...       ...
# 16971  19217          -40      0.0  18603       583477        None        53
# 16972  19218          -40      0.0  18604       583645        None        53
# 16973  19219          -40      0.0  18605       583667        None        53
# 16974  19220          -40      0.0  18606       583691        None        53
# 16975  19221          -40      0.0  18607       583756        None       104
#
#        owner_id  update_id  parent
# ...

# %%
tble.set_index('id')['mimetype'].unique()
# Out:
# array([None, 'Repository', 'text/plain', 'text/x-python', 'Directory',
#        'application/omero-log-file', 'application/pdf',
#        'application/json', 'image/jpeg', 'image/tiff',
#        'application/octet-stream', 'application/msword',
#        'application/zip', 'text/csv', 'JPEG', 'application/vnd.ms-excel',
#        'image/png'], dtype=object)

# %%
tble.shape
# Out:
# (42829, 19)

# %%
tble[tble['mimetype'] == "image/tiff"]
# Out:
#           id atime ctime  permissions  \
# 202      326   NaT   NaT          -56
# 25434  27225   NaT   NaT          -56
#
#                                            hash    mimetype  \
# 202    bde6c9dff3f0e5e1e9adb6c920ebd683481e0506  image/tiff
# 25434  26eca34c8807e00bfd2d2dfc3143ebbb21fd6187  image/tiff
#
#                         mtime            name path       size  version  \
# 202   2014-11-18 15:46:12.052  roiFigure.tiff       7225052.0      NaN
# 25434 2015-04-27 14:23:54.423   20150212.tiff       5925533.0      NaN
#
#        creation_id external_id  group_id  owner_id  update_id  hasher  repo  \
# 202           5859        None        54        56       5860     NaN  None
# 25434       345190        None       103         2     345191     NaN  None
#
#       params
# 202     None
# 25434   None

# %%
datasetimagelink.head()
# Out:
#     id  permissions  version  child  creation_id external_id  group_id  \
# 0  289         -120      0.0    285        24066        None        64
# 1  290         -120      0.0    286        24092        None        64
# 2   52         -120      0.0     52          959        None         0
# 3   53         -120      0.0     53          960        None         0
# 4   54         -120      0.0     54         1000        None         0
#
#    owner_id  update_id  parent
# 0       153      24066      93
# 1       153      24092      93
# 2         0        959      52
# 3         0        960      52
# 4         0       1000      52

# %%
with engine.connect() as conn: 
    microscopetype = pd.read_sql_table("microscopetype", conn)

# %%
microscopetype
# Out:
#    id  permissions              value external_id
# 0   1          -52            Upright        None
# 1   2          -52           Inverted        None
# 2   3          -52         Dissection        None
# 3   4          -52  Electrophysiology        None
# 4   5          -52              Other        None
# 5   6          -52            Unknown        None

# %%
with engine.connect() as conn: 
    dataset = pd.read_sql_table("dataset", conn)

# %%
dataset
# Out:
#       id description  permissions                   name version  creation_id  \
# 0    515        None          -40     dendra-lifeact5-M3    None       328111
# 1     52                     -120                 Demo 1    None          936
# 2    527                      -56                 Apo M2    None       334152
# 3    528                      -56         Apo Z1 inversé    None       334153
# 4    530                      -40  AxioImager M2 (avril)    None       339905
# ..   ...         ...          ...                    ...     ...          ...
# 415  889                      -56                    780    None       576315
# 416  891                      -56  780 individual images    None       576781
# 417  892                      -56                Apotome    None       578987
# 418  894                      -40     Observer Z1 (mars)    None       583179
# 419  895                      -40     Observer Z1 (mars)    None       583632
#
# ...

# %%
set(dataset['owner_id'].unique()) == set(datasetimagelink['owner_id'].unique())
# Out:
# True

# %%
with engine.connect() as conn: 
    fileset = pd.read_sql_table("fileset", conn)

# %%
fileset
# Out:
#           id  permissions                          templateprefix version  \
# 0         52         -120         root_0/2014-11/05/11-01-19.386/    None
# 1         53         -120         root_0/2014-11/05/11-01-35.526/    None
# 2         54         -120         root_0/2014-11/05/11-01-45.152/    None
# 3         55         -120         root_0/2014-11/05/11-01-59.252/    None
# 4         56         -120         root_0/2014-11/05/11-02-08.885/    None
# ...      ...          ...                                     ...     ...
# 12832  14275          -40  Metrologie_52/2016-03/25/08-36-29.630/    None
# 12833  14276          -40  Metrologie_52/2016-03/25/13-53-35.217/    None
# 12834  14277          -40  Metrologie_52/2016-03/25/13-53-36.639/    None
# 12835  14278          -40  Metrologie_52/2016-03/25/13-53-37.780/    None
# 12836  14279          -40  Metrology_404/2016-03/25/13-58-32.876/    None
#
#        creation_id external_id  group_id  owner_id  update_id
# ...

# %%
fileset[fileset["owner_id"]==0]
# Out:
#         id  permissions                   templateprefix version  creation_id  \
# 0       52         -120  root_0/2014-11/05/11-01-19.386/    None          943
# 1       53         -120  root_0/2014-11/05/11-01-35.526/    None          954
# 2       54         -120  root_0/2014-11/05/11-01-45.152/    None          971
# 3       55         -120  root_0/2014-11/05/11-01-59.252/    None         1013
# 4       56         -120  root_0/2014-11/05/11-02-08.885/    None         1039
# ...    ...          ...                              ...     ...          ...
# 3806  4044         -120  root_0/2015-02/04/14-31-08.779/    None       150773
# 3815  4101         -120  root_0/2015-02/12/10-58-20.358/    None       152612
# 3829  2928          -40  root_0/2015-01/12/15-55-32.311/    None       101624
# 3830  2929          -40  root_0/2015-01/12/15-55-37.593/    None       101642
# 4153  3900         -120  root_0/2015-01/27/14-49-19.019/    None       141113
#
# ...

# %%
tble[tble["id"] == 52]
# Out:
#     id atime ctime  permissions  hash   mimetype mtime     name     path  \
# 46  52   NaT   NaT         -120  None  Directory   NaT  2014-11  root_0/
#
#     size  version  creation_id external_id  group_id  owner_id  update_id  \
# 46   NaN      0.0          673        None         1         0        673
#
#     hasher                                  repo params
# 46     NaN  9077bd18-f90d-4109-9a83-baa3944361a8   None
